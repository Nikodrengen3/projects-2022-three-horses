# %% [markdown]
# # Inaugural Project

# %% [markdown]
# > **Note the following:**
# > 1. This is an example of how to structure your **inaugural project**.
# > 1. Remember the general advice on structuring and commenting your code from [lecture 5](https://numeconcopenhagen.netlify.com/lectures/Workflow_and_debugging).
# > 1. Remember this [guide](https://www.markdownguide.org/basic-syntax/) on markdown and (a bit of) latex.
# > 1. Turn on automatic numbering by clicking on the small icon on top of the table of contents in the left sidebar.
# > 1. The `inauguralproject.py` file includes a function which can be used multiple times in this notebook.

# %% [markdown]
# Imports and set magics:

# %%
import numpy as np

# autoreload modules when code is run. Otherwise, python will not see recent changes. 
# %load_ext autoreload
# %autoreload 2

# Import your own code
#import inauguralproject

# %% [markdown]
# # Question 1

# %% [markdown]
# **Explain how you solve the model**

# %%
# iii) We start with a fixed x of 0.5 and create a grit containing the range
N=500
q = np.linspace(0.01,0.5,N)
x = 0.5

#applying the parametrization
y = 1
p = 0.2
zeta=-2

shape_tuple = (N)
u_values = np.empty(shape_tuple)


#defining the utility function
def u_func(p,y,x,q,zeta):
    return p*((y-x+q-p*q)**(1+zeta))/(1+zeta)+(1-p)*((y-p*q)**(1+zeta))/(1+zeta)
#print(p*((y-x+q-p*q)**(1+zeta))/(1+zeta)+(1-p)*((y-p*q)**(1+zeta))/(1+zeta))


#i) Creating a loop that returns the agents' optimal insurance coverage


# ii) creating the grid of x a range between 0.01 and 0.09
x = np.linspace(0.01,0.9,N)

# iii) For every value x we find the optimal insurance q.
for ind, vx in enumerate(x):
    q_save=np.empty(N)
    q_best = 0.01
    u_best = u_func(p,y,vx,0.01,zeta)
    q_value=np.linspace(0.01,vx,N)
    for count, value in enumerate(q_value):
        u_values[count]=u_func(p,y,vx,value,zeta)
        if u_values[count]>=u_best:
            u_best=u_values[count]
            q_best=value

    print(f'For a value x of {vx} {q_best} is the optimal insurance with utility of {u_best}')       
    q_save[ind]=q_best
    #print(u_values)
        

# iv) Plotting the x's and q*s
import matplotlib.pyplot as plt 
plt.plot(x, q_save, color = "g", marker = "o", linestyle= "--", linewidth = 3,
        markersize = 2)
plt.title("Agents optimal insurance coverage")
plt.xlabel("x")
plt.ylabel("q*")
plt.show()
# Outer loop over different values of x
# Out:
# For a value x of 0.01 0.01 is the optimal insurance with utility of -1.0020040080160322
# For a value x of 0.011783567134268537 0.011783567134268537 is the optimal insurance with utility of -1.0023622806453687
# For a value x of 0.013567134268537074 0.013567134268537074 is the optimal insurance with utility of -1.0027208095714626
# For a value x of 0.015350701402805611 0.015350701402805611 is the optimal insurance with utility of -1.0030795950694316
# For a value x of 0.01713426853707415 0.01713426853707415 is the optimal insurance with utility of -1.0034386374147881
# For a value x of 0.018917835671342684 0.018917835671342684 is the optimal insurance with utility of -1.0037979368834389
# For a value x of 0.020701402805611224 0.020701402805611224 is the optimal insurance with utility of -1.0041574937516853
# For a value x of 0.022484969939879758 0.022484969939879758 is the optimal insurance with utility of -1.0045173082962262
# For a value x of 0.0242685370741483 0.0242685370741483 is the optimal insurance with utility of -1.0048773807941553
# For a value x of 0.026052104208416832 0.026052104208416832 is the optimal insurance with utility of -1.0052377115229656
# For a value x of 0.027835671342685372 0.027835671342685372 is the optimal insurance with utility of -1.0055983007605467
# For a value x of 0.029619238476953906 0.029619238476953906 is the optimal insurance with utility of -1.0059591487851884
# For a value x of 0.03140280561122245 0.03140280561122245 is the optimal insurance with utility of -1.0063202558755793
# For a value x of 0.03318637274549098 0.03318637274549098 is the optimal insurance with utility of -1.0066816223108084
# For a value x of 0.03496993987975952 0.03496993987975952 is the optimal insurance with utility of -1.0070432483703657
# For a value x of 0.036753507014028054 0.036753507014028054 is the optimal insurance with utility of -1.0074051343341435
# For a value x of 0.038537074148296595 0.038537074148296595 is the optimal insurance with utility of -1.0077672804824358
# For a value x of 0.04032064128256513 0.04032064128256513 is the optimal insurance with utility of -1.00812968709594
# For a value x of 0.04210420841683367 0.04210420841683367 is the optimal insurance with utility of -1.0084923544557578
# For a value x of 0.0438877755511022 0.0438877755511022 is the optimal insurance with utility of -1.008855282843395
# For a value x of 0.04567134268537074 0.04567134268537074 is the optimal insurance with utility of -1.0092184725407631
# For a value x of 0.047454909819639284 0.047454909819639284 is the optimal insurance with utility of -1.0095819238301798
# For a value x of 0.04923847695390782 0.04923847695390782 is the optimal insurance with utility of -1.0099456369943693
# For a value x of 0.05102204408817635 0.05102204408817635 is the optimal insurance with utility of -1.010309612316464
# For a value x of 0.05280561122244489 0.05280561122244489 is the optimal insurance with utility of -1.0106738500800034
# For a value x of 0.05458917835671343 0.05458917835671343 is the optimal insurance with utility of -1.0110383505689369
# For a value x of 0.056372745490981965 0.056372745490981965 is the optimal insurance with utility of -1.011403114067624
# For a value x of 0.0581563126252505 0.0581563126252505 is the optimal insurance with utility of -1.0117681408608343
# For a value x of 0.05993987975951904 0.05993987975951904 is the optimal insurance with utility of -1.012133431233748
# For a value x of 0.06172344689378758 0.06172344689378758 is the optimal insurance with utility of -1.0124989854719586
# For a value x of 0.06350701402805611 0.06350701402805611 is the optimal insurance with utility of -1.012864803861471
# For a value x of 0.06529058116232464 0.06529058116232464 is the optimal insurance with utility of -1.0132308866887048
# For a value x of 0.06707414829659318 0.06707414829659318 is the optimal insurance with utility of -1.0135972342404926
# For a value x of 0.06885771543086172 0.06885771543086172 is the optimal insurance with utility of -1.0139638468040835
# For a value x of 0.07064128256513026 0.07064128256513026 is the optimal insurance with utility of -1.014330724667141
# For a value x of 0.07242484969939879 0.07242484969939879 is the optimal insurance with utility of -1.0146978681177456
# For a value x of 0.07420841683366733 0.07420841683366733 is the optimal insurance with utility of -1.0150652774443953
# For a value x of 0.07599198396793587 0.07599198396793587 is the optimal insurance with utility of -1.0154329529360053
# For a value x of 0.0777755511022044 0.0777755511022044 is the optimal insurance with utility of -1.0158008948819106
# For a value x of 0.07955911823647294 0.07955911823647294 is the optimal insurance with utility of -1.016169103571865
# For a value x of 0.08134268537074148 0.08134268537074148 is the optimal insurance with utility of -1.0165375792960427
# For a value x of 0.08312625250501002 0.08312625250501002 is the optimal insurance with utility of -1.016906322345039
# For a value x of 0.08490981963927856 0.08490981963927856 is the optimal insurance with utility of -1.017275333009871
# For a value x of 0.08669338677354708 0.08669338677354708 is the optimal insurance with utility of -1.0176446115819784
# For a value x of 0.08847695390781563 0.08847695390781563 is the optimal insurance with utility of -1.0180141583532243
# For a value x of 0.09026052104208417 0.09026052104208417 is the optimal insurance with utility of -1.0183839736158957
# For a value x of 0.09204408817635269 0.09204408817635269 is the optimal insurance with utility of -1.0187540576627048
# For a value x of 0.09382765531062123 0.09382765531062123 is the optimal insurance with utility of -1.0191244107867887
# For a value x of 0.09561122244488977 0.09561122244488977 is the optimal insurance with utility of -1.0194950332817116
# For a value x of 0.09739478957915831 0.09739478957915831 is the optimal insurance with utility of -1.019865925441465
# For a value x of 0.09917835671342685 0.09917835671342685 is the optimal insurance with utility of -1.020237087560468
# For a value x of 0.10096192384769538 0.10096192384769538 is the optimal insurance with utility of -1.0206085199335684
# For a value x of 0.10274549098196392 0.10274549098196392 is the optimal insurance with utility of -1.0209802228560438
# For a value x of 0.10452905811623246 0.10452905811623246 is the optimal insurance with utility of -1.0213521966236019
# For a value x of 0.10631262525050099 0.10631262525050099 is the optimal insurance with utility of -1.0217244415323818
# For a value x of 0.10809619238476953 0.10809619238476953 is the optimal insurance with utility of -1.0220969578789543
# For a value x of 0.10987975951903807 0.10987975951903807 is the optimal insurance with utility of -1.0224697459603225
# For a value x of 0.11166332665330661 0.11166332665330661 is the optimal insurance with utility of -1.0228428060739234
# For a value x of 0.11344689378757515 0.11344689378757515 is the optimal insurance with utility of -1.0232161385176286
# For a value x of 0.11523046092184368 0.11523046092184368 is the optimal insurance with utility of -1.0235897435897436
# For a value x of 0.11701402805611222 0.11701402805611222 is the optimal insurance with utility of -1.0239636215890109
# For a value x of 0.11879759519038076 0.11879759519038076 is the optimal insurance with utility of -1.0243377728146092
# For a value x of 0.12058116232464929 0.12058116232464929 is the optimal insurance with utility of -1.0247121975661546
# For a value x of 0.12236472945891783 0.12236472945891783 is the optimal insurance with utility of -1.0250868961437012
# For a value x of 0.12414829659318637 0.12414829659318637 is the optimal insurance with utility of -1.0254618688477426
# For a value x of 0.1259318637274549 0.1259318637274549 is the optimal insurance with utility of -1.025837115979212
# For a value x of 0.12771543086172346 0.12771543086172346 is the optimal insurance with utility of -1.0262126378394831
# For a value x of 0.129498997995992 0.129498997995992 is the optimal insurance with utility of -1.0265884347303713
# For a value x of 0.13128256513026051 0.13128256513026051 is the optimal insurance with utility of -1.0269645069541344
# For a value x of 0.13306613226452907 0.13306613226452907 is the optimal insurance with utility of -1.0273408548134728
# For a value x of 0.1348496993987976 0.1348496993987976 is the optimal insurance with utility of -1.0277174786115313
# For a value x of 0.13663326653306615 0.13663326653306615 is the optimal insurance with utility of -1.0280943786518983
# For a value x of 0.13841683366733468 0.13841683366733468 is the optimal insurance with utility of -1.0284715552386094
# For a value x of 0.1402004008016032 0.1402004008016032 is the optimal insurance with utility of -1.0288490086761455
# For a value x of 0.14198396793587176 0.14198396793587176 is the optimal insurance with utility of -1.029226739269435
# For a value x of 0.14376753507014028 0.14376753507014028 is the optimal insurance with utility of -1.029604747323853
# For a value x of 0.1455511022044088 0.1455511022044088 is the optimal insurance with utility of -1.0299830331452255
# For a value x of 0.14733466933867737 0.14733466933867737 is the optimal insurance with utility of -1.0303615970398268
# For a value x of 0.1491182364729459 0.1491182364729459 is the optimal insurance with utility of -1.030740439314382
# For a value x of 0.15090180360721445 0.15090180360721445 is the optimal insurance with utility of -1.0311195602760672
# For a value x of 0.15268537074148297 0.15268537074148297 is the optimal insurance with utility of -1.031498960232511
# For a value x of 0.1544689378757515 0.1544689378757515 is the optimal insurance with utility of -1.0318786394917945
# For a value x of 0.15625250501002005 0.15625250501002005 is the optimal insurance with utility of -1.032258598362453
# For a value x of 0.15803607214428858 0.15803607214428858 is the optimal insurance with utility of -1.0326388371534763
# For a value x of 0.15981963927855714 0.15981963927855714 is the optimal insurance with utility of -1.033019356174309
# For a value x of 0.16160320641282566 0.16160320641282566 is the optimal insurance with utility of -1.0334001557348533
# For a value x of 0.1633867735470942 0.1633867735470942 is the optimal insurance with utility of -1.0337812361454668
# For a value x of 0.16517034068136274 0.16517034068136274 is the optimal insurance with utility of -1.0341625977169668
# For a value x of 0.16695390781563127 0.16695390781563127 is the optimal insurance with utility of -1.0345442407606285
# For a value x of 0.1687374749498998 0.1687374749498998 is the optimal insurance with utility of -1.0349261655881865
# For a value x of 0.17052104208416835 0.17052104208416835 is the optimal insurance with utility of -1.0353083725118366
# For a value x of 0.17230460921843688 0.17230460921843688 is the optimal insurance with utility of -1.0356908618442353
# For a value x of 0.1740881763527054 0.1740881763527054 is the optimal insurance with utility of -1.0360736338985022
# For a value x of 0.17587174348697396 0.17587174348697396 is the optimal insurance with utility of -1.036456688988219
# For a value x of 0.17765531062124248 0.17765531062124248 is the optimal insurance with utility of -1.0368400274274316
# For a value x of 0.17943887775551104 0.17943887775551104 is the optimal insurance with utility of -1.037223649530651
# For a value x of 0.18122244488977957 0.18122244488977957 is the optimal insurance with utility of -1.037607555612854
# For a value x of 0.1830060120240481 0.1830060120240481 is the optimal insurance with utility of -1.0379917459894827
# For a value x of 0.18478957915831665 0.18478957915831665 is the optimal insurance with utility of -1.0383762209764482
# For a value x of 0.18657314629258517 0.18657314629258517 is the optimal insurance with utility of -1.0387609808901286
# For a value x of 0.18835671342685373 0.18835671342685373 is the optimal insurance with utility of -1.0391460260473717
# For a value x of 0.19014028056112225 0.19014028056112225 is the optimal insurance with utility of -1.0395313567654951
# For a value x of 0.19192384769539078 0.19192384769539078 is the optimal insurance with utility of -1.039916973362287
# For a value x of 0.19370741482965934 0.19370741482965934 is the optimal insurance with utility of -1.0403028761560078
# For a value x of 0.19549098196392786 0.19549098196392786 is the optimal insurance with utility of -1.0406890654653902
# For a value x of 0.1972745490981964 0.1972745490981964 is the optimal insurance with utility of -1.0410755416096404
# For a value x of 0.19905811623246494 0.19905811623246494 is the optimal insurance with utility of -1.041462304908439
# For a value x of 0.20084168336673347 0.20084168336673347 is the optimal insurance with utility of -1.0418493556819417
# For a value x of 0.202625250501002 0.202625250501002 is the optimal insurance with utility of -1.0422366942507801
# For a value x of 0.20440881763527055 0.20440881763527055 is the optimal insurance with utility of -1.0426243209360635
# For a value x of 0.20619238476953908 0.20619238476953908 is the optimal insurance with utility of -1.0430122360593785
# For a value x of 0.20797595190380763 0.20797595190380763 is the optimal insurance with utility of -1.0434004399427907
# For a value x of 0.20975951903807616 0.20975951903807616 is the optimal insurance with utility of -1.0437889329088452
# For a value x of 0.21154308617234469 0.21154308617234469 is the optimal insurance with utility of -1.0441777152805678
# For a value x of 0.21332665330661324 0.21332665330661324 is the optimal insurance with utility of -1.0445667873814657
# For a value x of 0.21511022044088177 0.21511022044088177 is the optimal insurance with utility of -1.0449561495355284
# For a value x of 0.21689378757515032 0.21689378757515032 is the optimal insurance with utility of -1.045345802067229
# For a value x of 0.21867735470941885 0.21867735470941885 is the optimal insurance with utility of -1.045735745301524
# For a value x of 0.22046092184368737 0.22046092184368737 is the optimal insurance with utility of -1.0461259795638556
# For a value x of 0.22224448897795593 0.22224448897795593 is the optimal insurance with utility of -1.046516505180152
# For a value x of 0.22402805611222446 0.22402805611222446 is the optimal insurance with utility of -1.0469073224768275
# For a value x of 0.22581162324649298 0.22581162324649298 is the optimal insurance with utility of -1.0472984317807852
# For a value x of 0.22759519038076154 0.22759519038076154 is the optimal insurance with utility of -1.047689833419416
# For a value x of 0.22937875751503006 0.22937875751503006 is the optimal insurance with utility of -1.0480815277206013
# For a value x of 0.2311623246492986 0.2311623246492986 is the optimal insurance with utility of -1.048473515012712
# For a value x of 0.23294589178356714 0.23294589178356714 is the optimal insurance with utility of -1.0488657956246112
# For a value x of 0.23472945891783567 0.23472945891783567 is the optimal insurance with utility of -1.049258369885654
# For a value x of 0.23651302605210422 0.23651302605210422 is the optimal insurance with utility of -1.0496512381256888
# For a value x of 0.23829659318637275 0.23829659318637275 is the optimal insurance with utility of -1.0500444006750587
# For a value x of 0.24008016032064128 0.24008016032064128 is the optimal insurance with utility of -1.050437857864601
# For a value x of 0.24186372745490983 0.24186372745490983 is the optimal insurance with utility of -1.0508316100256494
# For a value x of 0.24364729458917836 0.24364729458917836 is the optimal insurance with utility of -1.0512256574900354
# For a value x of 0.2454308617234469 0.2454308617234469 is the optimal insurance with utility of -1.0516200005900873
# For a value x of 0.24721442885771544 0.24721442885771544 is the optimal insurance with utility of -1.052014639658633
# For a value x of 0.24899799599198397 0.24899799599198397 is the optimal insurance with utility of -1.0524095750289992
# For a value x of 0.2507815631262525 0.2507815631262525 is the optimal insurance with utility of -1.0528048070350147
# For a value x of 0.252565130260521 0.252565130260521 is the optimal insurance with utility of -1.053200336011009
# For a value x of 0.25434869739478955 0.25434869739478955 is the optimal insurance with utility of -1.0535961622918144
# For a value x of 0.25613226452905813 0.25613226452905813 is the optimal insurance with utility of -1.053992286212767
# For a value x of 0.25791583166332666 0.25791583166332666 is the optimal insurance with utility of -1.0543887081097072
# For a value x of 0.2596993987975952 0.2596993987975952 is the optimal insurance with utility of -1.0547854283189806
# For a value x of 0.2614829659318637 0.2614829659318637 is the optimal insurance with utility of -1.0551824471774398
# For a value x of 0.2632665330661323 0.2632665330661323 is the optimal insurance with utility of -1.0555797650224443
# For a value x of 0.2650501002004008 0.2650501002004008 is the optimal insurance with utility of -1.0559773821918619
# For a value x of 0.26683366733466934 0.26683366733466934 is the optimal insurance with utility of -1.0563752990240702
# For a value x of 0.26861723446893787 0.26861723446893787 is the optimal insurance with utility of -1.056773515857956
# For a value x of 0.2704008016032064 0.2704008016032064 is the optimal insurance with utility of -1.0571720330329186
# For a value x of 0.272184368737475 0.272184368737475 is the optimal insurance with utility of -1.0575708508888682
# For a value x of 0.2739679358717435 0.2739679358717435 is the optimal insurance with utility of -1.0579699697662288
# For a value x of 0.27575150300601203 0.27575150300601203 is the optimal insurance with utility of -1.0583693900059388
# For a value x of 0.27753507014028056 0.27753507014028056 is the optimal insurance with utility of -1.058769111949451
# For a value x of 0.2793186372745491 0.2793186372745491 is the optimal insurance with utility of -1.0591691359387339
# For a value x of 0.2811022044088176 0.2811022044088176 is the optimal insurance with utility of -1.059569462316274
# For a value x of 0.2828857715430862 0.2828857715430862 is the optimal insurance with utility of -1.0599700914250756
# For a value x of 0.2846693386773547 0.2846693386773547 is the optimal insurance with utility of -1.0603710236086614
# For a value x of 0.28645290581162325 0.28645290581162325 is the optimal insurance with utility of -1.0607722592110747
# For a value x of 0.2882364729458918 0.2882364729458918 is the optimal insurance with utility of -1.0611737985768788
# For a value x of 0.2900200400801603 0.2900200400801603 is the optimal insurance with utility of -1.0615756420511597
# For a value x of 0.2918036072144289 0.2918036072144289 is the optimal insurance with utility of -1.0619777899795266
# For a value x of 0.2935871743486974 0.2935871743486974 is the optimal insurance with utility of -1.0623802427081115
# For a value x of 0.29537074148296594 0.29537074148296594 is the optimal insurance with utility of -1.0627830005835723
# For a value x of 0.29715430861723446 0.29715430861723446 is the optimal insurance with utility of -1.063186063953092
# For a value x of 0.298937875751503 0.298937875751503 is the optimal insurance with utility of -1.0635894331643811
# For a value x of 0.3007214428857716 0.3007214428857716 is the optimal insurance with utility of -1.0639931085656777
# For a value x of 0.3025050100200401 0.3025050100200401 is the optimal insurance with utility of -1.0643970905057485
# For a value x of 0.3042885771543086 0.3042885771543086 is the optimal insurance with utility of -1.064801379333891
# For a value x of 0.30607214428857715 0.30607214428857715 is the optimal insurance with utility of -1.0652059753999326
# For a value x of 0.3078557114228457 0.3078557114228457 is the optimal insurance with utility of -1.065610879054233
# For a value x of 0.30963927855711426 0.30963927855711426 is the optimal insurance with utility of -1.0660160906476852
# For a value x of 0.3114228456913828 0.3114228456913828 is the optimal insurance with utility of -1.0664216105317148
# For a value x of 0.3132064128256513 0.3132064128256513 is the optimal insurance with utility of -1.0668274390582841
# For a value x of 0.31498997995991984 0.31498997995991984 is the optimal insurance with utility of -1.0672335765798908
# For a value x of 0.31677354709418837 0.31677354709418837 is the optimal insurance with utility of -1.0676400234495684
# For a value x of 0.3185571142284569 0.3185571142284569 is the optimal insurance with utility of -1.0680467800208902
# For a value x of 0.3203406813627255 0.3203406813627255 is the optimal insurance with utility of -1.0684538466479672
# For a value x of 0.322124248496994 0.322124248496994 is the optimal insurance with utility of -1.0688612236854507
# For a value x of 0.32390781563126253 0.32390781563126253 is the optimal insurance with utility of -1.0692689114885336
# For a value x of 0.32569138276553106 0.32569138276553106 is the optimal insurance with utility of -1.069676910412951
# For a value x of 0.3274749498997996 0.3274749498997996 is the optimal insurance with utility of -1.0700852208149805
# For a value x of 0.32925851703406817 0.32925851703406817 is the optimal insurance with utility of -1.070493843051444
# For a value x of 0.3310420841683367 0.3310420841683367 is the optimal insurance with utility of -1.0709027774797086
# For a value x of 0.3328256513026052 0.3328256513026052 is the optimal insurance with utility of -1.0713120244576886
# For a value x of 0.33460921843687375 0.33460921843687375 is the optimal insurance with utility of -1.0717215843438443
# For a value x of 0.33639278557114227 0.33639278557114227 is the optimal insurance with utility of -1.0721314574971854
# For a value x of 0.3381763527054108 0.3381763527054108 is the optimal insurance with utility of -1.0725416442772704
# For a value x of 0.3399599198396794 0.3399599198396794 is the optimal insurance with utility of -1.0729521450442083
# For a value x of 0.3417434869739479 0.3417434869739479 is the optimal insurance with utility of -1.0733629601586598
# For a value x of 0.34352705410821643 0.34352705410821643 is the optimal insurance with utility of -1.0737740899818384
# For a value x of 0.34531062124248496 0.34531062124248496 is the optimal insurance with utility of -1.074185534875511
# For a value x of 0.3470941883767535 0.3470941883767535 is the optimal insurance with utility of -1.0745972952019984
# For a value x of 0.34887775551102207 0.34887775551102207 is the optimal insurance with utility of -1.0750093713241788
# For a value x of 0.3506613226452906 0.3506613226452906 is the optimal insurance with utility of -1.0754217636054861
# For a value x of 0.3524448897795591 0.3524448897795591 is the optimal insurance with utility of -1.0758344724099123
# For a value x of 0.35422845691382765 0.35422845691382765 is the optimal insurance with utility of -1.0762474981020085
# For a value x of 0.3560120240480962 0.3560120240480962 is the optimal insurance with utility of -1.0766608410468854
# For a value x of 0.35779559118236476 0.35779559118236476 is the optimal insurance with utility of -1.0770745016102157
# For a value x of 0.3595791583166333 0.3595791583166333 is the optimal insurance with utility of -1.0774884801582332
# For a value x of 0.3613627254509018 0.3613627254509018 is the optimal insurance with utility of -1.0779027770577359
# For a value x of 0.36314629258517034 0.36314629258517034 is the optimal insurance with utility of -1.0783173926760856
# For a value x of 0.36492985971943886 0.36492985971943886 is the optimal insurance with utility of -1.0787323273812097
# For a value x of 0.36671342685370745 0.36671342685370745 is the optimal insurance with utility of -1.0791475815416023
# For a value x of 0.368496993987976 0.368496993987976 is the optimal insurance with utility of -1.079563155526325
# For a value x of 0.3702805611222445 0.3702805611222445 is the optimal insurance with utility of -1.0799790497050077
# For a value x of 0.372064128256513 0.372064128256513 is the optimal insurance with utility of -1.080395264447851
# For a value x of 0.37384769539078155 0.37384769539078155 is the optimal insurance with utility of -1.0808118001256255
# For a value x of 0.3756312625250501 0.3756312625250501 is the optimal insurance with utility of -1.0812286571096743
# For a value x of 0.37741482965931866 0.37741482965931866 is the optimal insurance with utility of -1.0816458357719136
# For a value x of 0.3791983967935872 0.3791983967935872 is the optimal insurance with utility of -1.0820633364848338
# For a value x of 0.3809819639278557 0.3809819639278557 is the optimal insurance with utility of -1.0824811596215003
# For a value x of 0.38276553106212424 0.38276553106212424 is the optimal insurance with utility of -1.0828993055555556
# For a value x of 0.38454909819639277 0.38454909819639277 is the optimal insurance with utility of -1.083317774661219
# For a value x of 0.38633266533066135 0.38633266533066135 is the optimal insurance with utility of -1.083736567313289
# For a value x of 0.3881162324649299 0.3881162324649299 is the optimal insurance with utility of -1.0841556838871436
# For a value x of 0.3898997995991984 0.3898997995991984 is the optimal insurance with utility of -1.0845751247587418
# For a value x of 0.39168336673346693 0.39168336673346693 is the optimal insurance with utility of -1.0849948903046247
# For a value x of 0.39346693386773546 0.39346693386773546 is the optimal insurance with utility of -1.0854149809019167
# For a value x of 0.395250501002004 0.395250501002004 is the optimal insurance with utility of -1.085835396928326
# For a value x of 0.39703406813627257 0.39703406813627257 is the optimal insurance with utility of -1.086256138762147
# For a value x of 0.3988176352705411 0.3988176352705411 is the optimal insurance with utility of -1.0866772067822594
# For a value x of 0.4006012024048096 0.4006012024048096 is the optimal insurance with utility of -1.0870986013681323
# For a value x of 0.40238476953907815 0.40238476953907815 is the optimal insurance with utility of -1.0875203228998218
# For a value x of 0.4041683366733467 0.4041683366733467 is the optimal insurance with utility of -1.0879423717579753
# For a value x of 0.40595190380761526 0.40595190380761526 is the optimal insurance with utility of -1.088364748323831
# For a value x of 0.4077354709418838 0.4077354709418838 is the optimal insurance with utility of -1.0887874529792192
# For a value x of 0.4095190380761523 0.4095190380761523 is the optimal insurance with utility of -1.089210486106564
# For a value x of 0.41130260521042084 0.41130260521042084 is the optimal insurance with utility of -1.0896338480888828
# For a value x of 0.41308617234468936 0.41308617234468936 is the optimal insurance with utility of -1.0900575393097904
# For a value x of 0.41486973947895794 0.41486973947895794 is the optimal insurance with utility of -1.0904815601534978
# For a value x of 0.41665330661322647 0.41665330661322647 is the optimal insurance with utility of -1.090905911004814
# For a value x of 0.418436873747495 0.418436873747495 is the optimal insurance with utility of -1.0913305922491472
# For a value x of 0.4202204408817635 0.4202204408817635 is the optimal insurance with utility of -1.0917556042725058
# For a value x of 0.42200400801603205 0.42200400801603205 is the optimal insurance with utility of -1.0921809474615003
# For a value x of 0.42378757515030063 0.42378757515030063 is the optimal insurance with utility of -1.092606622203343
# For a value x of 0.42557114228456916 0.42557114228456916 is the optimal insurance with utility of -1.0930326288858514
# For a value x of 0.4273547094188377 0.4273547094188377 is the optimal insurance with utility of -1.0934589678974471
# For a value x of 0.4291382765531062 0.4291382765531062 is the optimal insurance with utility of -1.0938856396271581
# For a value x of 0.43092184368737474 0.43092184368737474 is the optimal insurance with utility of -1.09431264446462
# For a value x of 0.43270541082164327 0.43270541082164327 is the optimal insurance with utility of -1.0947399828000772
# For a value x of 0.43448897795591185 0.43448897795591185 is the optimal insurance with utility of -1.0951676550243834
# For a value x of 0.4362725450901804 0.4362725450901804 is the optimal insurance with utility of -1.0955956615290037
# For a value x of 0.4380561122244489 0.4380561122244489 is the optimal insurance with utility of -1.096024002706015
# For a value x of 0.43983967935871743 0.43983967935871743 is the optimal insurance with utility of -1.0964526789481086
# For a value x of 0.44162324649298595 0.44162324649298595 is the optimal insurance with utility of -1.096881690648589
# For a value x of 0.44340681362725454 0.44340681362725454 is the optimal insurance with utility of -1.0973110382013775
# For a value x of 0.44519038076152306 0.44519038076152306 is the optimal insurance with utility of -1.0977407220010122
# For a value x of 0.4469739478957916 0.4469739478957916 is the optimal insurance with utility of -1.0981707424426488
# For a value x of 0.4487575150300601 0.4487575150300601 is the optimal insurance with utility of -1.0986010999220632
# For a value x of 0.45054108216432864 0.45054108216432864 is the optimal insurance with utility of -1.0990317948356518
# For a value x of 0.45232464929859717 0.45232464929859717 is the optimal insurance with utility of -1.0994628275804326
# For a value x of 0.45410821643286575 0.45410821643286575 is the optimal insurance with utility of -1.099894198554047
# For a value x of 0.4558917835671343 0.4558917835671343 is the optimal insurance with utility of -1.10032590815476
# For a value x of 0.4576753507014028 0.4576753507014028 is the optimal insurance with utility of -1.1007579567814632
# For a value x of 0.45945891783567133 0.45945891783567133 is the optimal insurance with utility of -1.101190344833674
# For a value x of 0.46124248496993986 0.46124248496993986 is the optimal insurance with utility of -1.1016230727115381
# For a value x of 0.46302605210420844 0.46302605210420844 is the optimal insurance with utility of -1.1020561408158307
# For a value x of 0.46480961923847697 0.46480961923847697 is the optimal insurance with utility of -1.1024895495479572
# For a value x of 0.4665931863727455 0.4665931863727455 is the optimal insurance with utility of -1.1029232993099547
# For a value x of 0.468376753507014 0.468376753507014 is the optimal insurance with utility of -1.103357390504493
# For a value x of 0.47016032064128255 0.47016032064128255 is the optimal insurance with utility of -1.1037918235348767
# For a value x of 0.47194388777555113 0.47194388777555113 is the optimal insurance with utility of -1.1042265988050453
# For a value x of 0.47372745490981966 0.47372745490981966 is the optimal insurance with utility of -1.1046617167195754
# For a value x of 0.4755110220440882 0.4755110220440882 is the optimal insurance with utility of -1.1050971776836809
# For a value x of 0.4772945891783567 0.4772945891783567 is the optimal insurance with utility of -1.1055329821032156
# For a value x of 0.47907815631262524 0.47907815631262524 is the optimal insurance with utility of -1.1059691303846733
# For a value x of 0.4808617234468938 0.4808617234468938 is the optimal insurance with utility of -1.10640562293519
# For a value x of 0.48264529058116235 0.48264529058116235 is the optimal insurance with utility of -1.106842460162544
# For a value x of 0.48442885771543087 0.48442885771543087 is the optimal insurance with utility of -1.1072796424751583
# For a value x of 0.4862124248496994 0.4862124248496994 is the optimal insurance with utility of -1.1077171702821016
# For a value x of 0.4879959919839679 0.4879959919839679 is the optimal insurance with utility of -1.1081550439930892
# For a value x of 0.48977955911823645 0.48977955911823645 is the optimal insurance with utility of -1.108593264018484
# For a value x of 0.49156312625250503 0.49156312625250503 is the optimal insurance with utility of -1.1090318307692992
# For a value x of 0.49334669338677356 0.49334669338677356 is the optimal insurance with utility of -1.109470744657198
# For a value x of 0.4951302605210421 0.4951302605210421 is the optimal insurance with utility of -1.1099100060944962
# For a value x of 0.4969138276553106 0.4969138276553106 is the optimal insurance with utility of -1.1103496154941612
# For a value x of 0.49869739478957914 0.49869739478957914 is the optimal insurance with utility of -1.1107895732698172
# For a value x of 0.5004809619238477 0.5004809619238477 is the optimal insurance with utility of -1.1112298798357427
# For a value x of 0.5022645290581162 0.5022645290581162 is the optimal insurance with utility of -1.1116705356068741
# For a value x of 0.5040480961923848 0.5040480961923848 is the optimal insurance with utility of -1.1121115409988054
# For a value x of 0.5058316633266533 0.5058316633266533 is the optimal insurance with utility of -1.112552896427791
# For a value x of 0.5076152304609218 0.5076152304609218 is the optimal insurance with utility of -1.1129946023107462
# For a value x of 0.5093987975951904 0.5093987975951904 is the optimal insurance with utility of -1.1134366590652487
# For a value x of 0.5111823647294589 0.5111823647294589 is the optimal insurance with utility of -1.1138790671095395
# For a value x of 0.5129659318637274 0.5129659318637274 is the optimal insurance with utility of -1.1143218268625252
# For a value x of 0.514749498997996 0.514749498997996 is the optimal insurance with utility of -1.1147649387437784
# For a value x of 0.5165330661322646 0.5165330661322646 is the optimal insurance with utility of -1.115208403173539
# For a value x of 0.5183166332665331 0.5183166332665331 is the optimal insurance with utility of -1.1156522205727164
# For a value x of 0.5201002004008016 0.5201002004008016 is the optimal insurance with utility of -1.1160963913628903
# For a value x of 0.5218837675350702 0.5218837675350702 is the optimal insurance with utility of -1.1165409159663113
# For a value x of 0.5236673346693387 0.5236673346693387 is the optimal insurance with utility of -1.1169857948059043
# For a value x of 0.5254509018036072 0.5254509018036072 is the optimal insurance with utility of -1.117431028305267
# For a value x of 0.5272344689378757 0.5272344689378757 is the optimal insurance with utility of -1.117876616888674
# For a value x of 0.5290180360721443 0.5290180360721443 is the optimal insurance with utility of -1.1183225609810759
# For a value x of 0.5308016032064128 0.5308016032064128 is the optimal insurance with utility of -1.1187688610081026
# For a value x of 0.5325851703406813 0.5325851703406813 is the optimal insurance with utility of -1.1192155173960634
# For a value x of 0.53436873747495 0.53436873747495 is the optimal insurance with utility of -1.1196625305719479
# For a value x of 0.5361523046092185 0.5361523046092185 is the optimal insurance with utility of -1.1201099009634292
# For a value x of 0.537935871743487 0.537935871743487 is the optimal insurance with utility of -1.1205576289988637
# For a value x of 0.5397194388777555 0.5397194388777555 is the optimal insurance with utility of -1.121005715107293
# For a value x of 0.5415030060120241 0.5415030060120241 is the optimal insurance with utility of -1.1214541597184453
# For a value x of 0.5432865731462926 0.5432865731462926 is the optimal insurance with utility of -1.1219029632627366
# For a value x of 0.5450701402805611 0.5450701402805611 is the optimal insurance with utility of -1.1223521261712723
# For a value x of 0.5468537074148296 0.5468537074148296 is the optimal insurance with utility of -1.1228016488758483
# For a value x of 0.5486372745490982 0.5486372745490982 is the optimal insurance with utility of -1.1232515318089527
# For a value x of 0.5504208416833667 0.5504208416833667 is the optimal insurance with utility of -1.123701775403767
# For a value x of 0.5522044088176352 0.5522044088176352 is the optimal insurance with utility of -1.1241523800941675
# For a value x of 0.5539879759519039 0.5539879759519039 is the optimal insurance with utility of -1.1246033463147267
# For a value x of 0.5557715430861724 0.5557715430861724 is the optimal insurance with utility of -1.1250546745007148
# For a value x of 0.5575551102204409 0.5575551102204409 is the optimal insurance with utility of -1.1255063650881008
# For a value x of 0.5593386773547094 0.5593386773547094 is the optimal insurance with utility of -1.1259584185135543
# For a value x of 0.561122244488978 0.561122244488978 is the optimal insurance with utility of -1.1264108352144468
# For a value x of 0.5629058116232465 0.5629058116232465 is the optimal insurance with utility of -1.1268636156288532
# For a value x of 0.564689378757515 0.564689378757515 is the optimal insurance with utility of -1.1273167601955523
# For a value x of 0.5664729458917835 0.5664729458917835 is the optimal insurance with utility of -1.1277702693540295
# For a value x of 0.5682565130260521 0.5682565130260521 is the optimal insurance with utility of -1.128224143544478
# For a value x of 0.5700400801603206 0.5700400801603206 is the optimal insurance with utility of -1.1286783832077991
# For a value x of 0.5718236472945892 0.5718236472945892 is the optimal insurance with utility of -1.129132988785605
# For a value x of 0.5736072144288578 0.5736072144288578 is the optimal insurance with utility of -1.12958796072022
# For a value x of 0.5753907815631263 0.5753907815631263 is the optimal insurance with utility of -1.1300432994546805
# For a value x of 0.5771743486973948 0.5771743486973948 is the optimal insurance with utility of -1.1304990054327386
# For a value x of 0.5789579158316633 0.5789579158316633 is the optimal insurance with utility of -1.1309550790988623
# For a value x of 0.5807414829659319 0.5807414829659319 is the optimal insurance with utility of -1.1314115208982365
# For a value x of 0.5825250501002004 0.5825250501002004 is the optimal insurance with utility of -1.131868331276766
# For a value x of 0.5843086172344689 0.5843086172344689 is the optimal insurance with utility of -1.1323255106810746
# For a value x of 0.5860921843687374 0.5860921843687374 is the optimal insurance with utility of -1.1327830595585096
# For a value x of 0.587875751503006 0.587875751503006 is the optimal insurance with utility of -1.1332409783571413
# For a value x of 0.5896593186372745 0.5896593186372745 is the optimal insurance with utility of -1.1336992675257638
# For a value x of 0.5914428857715431 0.5914428857715431 is the optimal insurance with utility of -1.1341579275138987
# For a value x of 0.5932264529058117 0.5932264529058117 is the optimal insurance with utility of -1.1346169587717942
# For a value x of 0.5950100200400802 0.5950100200400802 is the optimal insurance with utility of -1.135076361750429
# For a value x of 0.5967935871743487 0.5967935871743487 is the optimal insurance with utility of -1.1355361369015111
# For a value x of 0.5985771543086172 0.5985771543086172 is the optimal insurance with utility of -1.1359962846774818
# For a value x of 0.6003607214428858 0.6003607214428858 is the optimal insurance with utility of -1.1364568055315156
# For a value x of 0.6021442885771543 0.6021442885771543 is the optimal insurance with utility of -1.1369176999175221
# For a value x of 0.6039278557114228 0.6039278557114228 is the optimal insurance with utility of -1.1373789682901478
# For a value x of 0.6057114228456913 0.6057114228456913 is the optimal insurance with utility of -1.1378406111047772
# For a value x of 0.6074949899799599 0.6074949899799599 is the optimal insurance with utility of -1.138302628817534
# For a value x of 0.6092785571142285 0.6092785571142285 is the optimal insurance with utility of -1.1387650218852836
# For a value x of 0.611062124248497 0.611062124248497 is the optimal insurance with utility of -1.139227790765634
# For a value x of 0.6128456913827656 0.6128456913827656 is the optimal insurance with utility of -1.1396909359169374
# For a value x of 0.6146292585170341 0.6146292585170341 is the optimal insurance with utility of -1.140154457798291
# For a value x of 0.6164128256513026 0.6164128256513026 is the optimal insurance with utility of -1.14061835686954
# For a value x of 0.6181963927855711 0.6181963927855711 is the optimal insurance with utility of -1.1410826335912774
# For a value x of 0.6199799599198397 0.6199799599198397 is the optimal insurance with utility of -1.1415472884248477
# For a value x of 0.6217635270541082 0.6217635270541082 is the optimal insurance with utility of -1.1420123218323461
# For a value x of 0.6235470941883767 0.6235470941883767 is the optimal insurance with utility of -1.1424777342766217
# For a value x of 0.6253306613226453 0.6253306613226453 is the optimal insurance with utility of -1.1429435262212775
# For a value x of 0.6271142284569138 0.6271142284569138 is the optimal insurance with utility of -1.143409698130674
# For a value x of 0.6288977955911824 0.6288977955911824 is the optimal insurance with utility of -1.1438762504699291
# For a value x of 0.630681362725451 0.630681362725451 is the optimal insurance with utility of -1.14434318370492
# For a value x of 0.6324649298597195 0.6324649298597195 is the optimal insurance with utility of -1.144810498302285
# For a value x of 0.634248496993988 0.634248496993988 is the optimal insurance with utility of -1.1452781947294253
# For a value x of 0.6360320641282565 0.6360320641282565 is the optimal insurance with utility of -1.1457462734545054
# For a value x of 0.637815631262525 0.637815631262525 is the optimal insurance with utility of -1.1462147349464564
# For a value x of 0.6395991983967936 0.6395991983967936 is the optimal insurance with utility of -1.1466835796749761
# For a value x of 0.6413827655310621 0.6413827655310621 is the optimal insurance with utility of -1.1471528081105316
# For a value x of 0.6431663326653306 0.6431663326653306 is the optimal insurance with utility of -1.147622420724359
# For a value x of 0.6449498997995992 0.6449498997995992 is the optimal insurance with utility of -1.1480924179884686
# For a value x of 0.6467334669338677 0.6467334669338677 is the optimal insurance with utility of -1.148562800375642
# For a value x of 0.6485170340681363 0.6485170340681363 is the optimal insurance with utility of -1.149033568359438
# For a value x of 0.6503006012024048 0.6503006012024048 is the optimal insurance with utility of -1.1495047224141903
# For a value x of 0.6520841683366734 0.6520841683366734 is the optimal insurance with utility of -1.1499762630150119
# For a value x of 0.6538677354709419 0.6538677354709419 is the optimal insurance with utility of -1.1504481906377957
# For a value x of 0.6556513026052104 0.6556513026052104 is the optimal insurance with utility of -1.1509205057592153
# For a value x of 0.657434869739479 0.657434869739479 is the optimal insurance with utility of -1.151393208856729
# For a value x of 0.6592184368737475 0.6592184368737475 is the optimal insurance with utility of -1.1518663004085778
# For a value x of 0.661002004008016 0.661002004008016 is the optimal insurance with utility of -1.1523397808937907
# For a value x of 0.6627855711422845 0.6627855711422845 is the optimal insurance with utility of -1.152813650792184
# For a value x of 0.6645691382765531 0.6645691382765531 is the optimal insurance with utility of -1.1532879105843632
# For a value x of 0.6663527054108216 0.6663527054108216 is the optimal insurance with utility of -1.153762560751726
# For a value x of 0.6681362725450902 0.6681362725450902 is the optimal insurance with utility of -1.154237601776462
# For a value x of 0.6699198396793588 0.6699198396793588 is the optimal insurance with utility of -1.1547130341415552
# For a value x of 0.6717034068136273 0.6717034068136273 is the optimal insurance with utility of -1.1551888583307868
# For a value x of 0.6734869739478958 0.6734869739478958 is the optimal insurance with utility of -1.1556650748287347
# For a value x of 0.6752705410821643 0.6752705410821643 is the optimal insurance with utility of -1.1561416841207763
# For a value x of 0.6770541082164329 0.6770541082164329 is the optimal insurance with utility of -1.1566186866930903
# For a value x of 0.6788376753507014 0.6788376753507014 is the optimal insurance with utility of -1.1570960830326584
# For a value x of 0.6806212424849699 0.6806212424849699 is the optimal insurance with utility of -1.1575738736272658
# For a value x of 0.6824048096192384 0.6824048096192384 is the optimal insurance with utility of -1.1580520589655046
# For a value x of 0.684188376753507 0.684188376753507 is the optimal insurance with utility of -1.1585306395367736
# For a value x of 0.6859719438877756 0.6859719438877756 is the optimal insurance with utility of -1.1590096158312817
# For a value x of 0.6877555110220441 0.6877555110220441 is the optimal insurance with utility of -1.1594889883400485
# For a value x of 0.6895390781563127 0.6895390781563127 is the optimal insurance with utility of -1.1599687575549067
# For a value x of 0.6913226452905812 0.6913226452905812 is the optimal insurance with utility of -1.1604489239685027
# For a value x of 0.6931062124248497 0.6931062124248497 is the optimal insurance with utility of -1.1609294880742995
# For a value x of 0.6948897795591182 0.6948897795591182 is the optimal insurance with utility of -1.1614104503665774
# For a value x of 0.6966733466933868 0.6966733466933868 is the optimal insurance with utility of -1.1618918113404366
# For a value x of 0.6984569138276553 0.6984569138276553 is the optimal insurance with utility of -1.1623735714917982
# For a value x of 0.7002404809619238 0.7002404809619238 is the optimal insurance with utility of -1.162855731317406
# For a value x of 0.7020240480961923 0.7020240480961923 is the optimal insurance with utility of -1.1633382913148287
# For a value x of 0.7038076152304609 0.7038076152304609 is the optimal insurance with utility of -1.163821251982461
# For a value x of 0.7055911823647295 0.7055911823647295 is the optimal insurance with utility of -1.1643046138195259
# For a value x of 0.707374749498998 0.707374749498998 is the optimal insurance with utility of -1.1647883773260754
# For a value x of 0.7091583166332666 0.7091583166332666 is the optimal insurance with utility of -1.1652725430029938
# For a value x of 0.7109418837675351 0.7109418837675351 is the optimal insurance with utility of -1.165757111351998
# For a value x of 0.7127254509018036 0.7127254509018036 is the optimal insurance with utility of -1.16624208287564
# For a value x of 0.7145090180360721 0.7145090180360721 is the optimal insurance with utility of -1.1667274580773082
# For a value x of 0.7162925851703407 0.7162925851703407 is the optimal insurance with utility of -1.1672132374612294
# For a value x of 0.7180761523046092 0.7180761523046092 is the optimal insurance with utility of -1.167699421532471
# For a value x of 0.7198597194388777 0.7198597194388777 is the optimal insurance with utility of -1.1681860107969417
# For a value x of 0.7216432865731462 0.7216432865731462 is the optimal insurance with utility of -1.168673005761394
# For a value x of 0.7234268537074149 0.7234268537074149 is the optimal insurance with utility of -1.1691604069334258
# For a value x of 0.7252104208416834 0.7252104208416834 is the optimal insurance with utility of -1.1696482148214822
# For a value x of 0.7269939879759519 0.7269939879759519 is the optimal insurance with utility of -1.170136429934857
# For a value x of 0.7287775551102205 0.7287775551102205 is the optimal insurance with utility of -1.1706250527836948
# For a value x of 0.730561122244489 0.730561122244489 is the optimal insurance with utility of -1.1711140838789926
# For a value x of 0.7323446893787575 0.7323446893787575 is the optimal insurance with utility of -1.1716035237326023
# For a value x of 0.734128256513026 0.734128256513026 is the optimal insurance with utility of -1.17209337285723
# For a value x of 0.7359118236472946 0.7359118236472946 is the optimal insurance with utility of -1.172583631766442
# For a value x of 0.7376953907815631 0.7376953907815631 is the optimal insurance with utility of -1.1730743009746625
# For a value x of 0.7394789579158316 0.7394789579158316 is the optimal insurance with utility of -1.1735653809971778
# For a value x of 0.7412625250501002 0.7412625250501002 is the optimal insurance with utility of -1.1740568723501372
# For a value x of 0.7430460921843688 0.7430460921843688 is the optimal insurance with utility of -1.174548775550555
# For a value x of 0.7448296593186373 0.7448296593186373 is the optimal insurance with utility of -1.175041091116313
# For a value x of 0.7466132264529058 0.7466132264529058 is the optimal insurance with utility of -1.1755338195661598
# For a value x of 0.7483967935871744 0.7483967935871744 is the optimal insurance with utility of -1.1760269614197167
# For a value x of 0.7501803607214429 0.7501803607214429 is the optimal insurance with utility of -1.1765205171974764
# For a value x of 0.7519639278557114 0.7519639278557114 is the optimal insurance with utility of -1.177014487420805
# For a value x of 0.75374749498998 0.75374749498998 is the optimal insurance with utility of -1.177508872611946
# For a value x of 0.7555310621242485 0.7555310621242485 is the optimal insurance with utility of -1.1780036732940193
# For a value x of 0.757314629258517 0.757314629258517 is the optimal insurance with utility of -1.1784988899910254
# For a value x of 0.7590981963927855 0.7590981963927855 is the optimal insurance with utility of -1.178994523227846
# For a value x of 0.7608817635270541 0.7608817635270541 is the optimal insurance with utility of -1.1794905735302461
# For a value x of 0.7626653306613227 0.7626653306613227 is the optimal insurance with utility of -1.1799870414248759
# For a value x of 0.7644488977955912 0.7644488977955912 is the optimal insurance with utility of -1.1804839274392727
# For a value x of 0.7662324649298597 0.7662324649298597 is the optimal insurance with utility of -1.1809812321018627
# For a value x of 0.7680160320641283 0.7680160320641283 is the optimal insurance with utility of -1.1814789559419632
# For a value x of 0.7697995991983968 0.7697995991983968 is the optimal insurance with utility of -1.1819770994897838
# For a value x of 0.7715831663326653 0.7715831663326653 is the optimal insurance with utility of -1.1824756632764295
# For a value x of 0.7733667334669339 0.7733667334669339 is the optimal insurance with utility of -1.1829746478338998
# For a value x of 0.7751503006012024 0.7751503006012024 is the optimal insurance with utility of -1.1834740536950954
# For a value x of 0.7769338677354709 0.7769338677354709 is the optimal insurance with utility of -1.1839738813938148
# For a value x of 0.7787174348697394 0.7787174348697394 is the optimal insurance with utility of -1.1844741314647602
# For a value x of 0.780501002004008 0.780501002004008 is the optimal insurance with utility of -1.1849748044435369
# For a value x of 0.7822845691382766 0.7822845691382766 is the optimal insurance with utility of -1.1854759008666567
# For a value x of 0.7840681362725451 0.7840681362725451 is the optimal insurance with utility of -1.185977421271539
# For a value x of 0.7858517034068137 0.7858517034068137 is the optimal insurance with utility of -1.1864793661965134
# For a value x of 0.7876352705410822 0.7876352705410822 is the optimal insurance with utility of -1.1869817361808208
# For a value x of 0.7894188376753507 0.7894188376753507 is the optimal insurance with utility of -1.1874845317646163
# For a value x of 0.7912024048096192 0.7912024048096192 is the optimal insurance with utility of -1.18798775348897
# For a value x of 0.7929859719438878 0.7929859719438878 is the optimal insurance with utility of -1.18849140189587
# For a value x of 0.7947695390781563 0.7947695390781563 is the optimal insurance with utility of -1.1889954775282237
# For a value x of 0.7965531062124248 0.7965531062124248 is the optimal insurance with utility of -1.18949998092986
# For a value x of 0.7983366733466933 0.7983366733466933 is the optimal insurance with utility of -1.1900049126455312
# For a value x of 0.800120240480962 0.800120240480962 is the optimal insurance with utility of -1.190510273220915
# For a value x of 0.8019038076152305 0.8019038076152305 is the optimal insurance with utility of -1.1910160632026163
# For a value x of 0.803687374749499 0.803687374749499 is the optimal insurance with utility of -1.1915222831381689
# For a value x of 0.8054709418837676 0.8054709418837676 is the optimal insurance with utility of -1.192028933576039
# For a value x of 0.8072545090180361 0.8072545090180361 is the optimal insurance with utility of -1.1925360150656252
# For a value x of 0.8090380761523046 0.8090380761523046 is the optimal insurance with utility of -1.1930435281572618
# For a value x of 0.8108216432865731 0.8108216432865731 is the optimal insurance with utility of -1.1935514734022197
# For a value x of 0.8126052104208417 0.8126052104208417 is the optimal insurance with utility of -1.1940598513527094
# For a value x of 0.8143887775551102 0.8143887775551102 is the optimal insurance with utility of -1.194568662561883
# For a value x of 0.8161723446893787 0.8161723446893787 is the optimal insurance with utility of -1.1950779075838351
# For a value x of 0.8179559118236472 0.8179559118236472 is the optimal insurance with utility of -1.1955875869736061
# For a value x of 0.8197394789579159 0.8197394789579159 is the optimal insurance with utility of -1.1960977012871834
# For a value x of 0.8215230460921844 0.8215230460921844 is the optimal insurance with utility of -1.1966082510815037
# For a value x of 0.8233066132264529 0.8233066132264529 is the optimal insurance with utility of -1.1971192369144552
# For a value x of 0.8250901803607215 0.8250901803607215 is the optimal insurance with utility of -1.1976306593448791
# For a value x of 0.82687374749499 0.82687374749499 is the optimal insurance with utility of -1.1981425189325727
# For a value x of 0.8286573146292585 0.8286573146292585 is the optimal insurance with utility of -1.1986548162382897
# For a value x of 0.830440881763527 0.830440881763527 is the optimal insurance with utility of -1.1991675518237441
# For a value x of 0.8322244488977956 0.8322244488977956 is the optimal insurance with utility of -1.199680726251611
# For a value x of 0.8340080160320641 0.8340080160320641 is the optimal insurance with utility of -1.2001943400855288
# For a value x of 0.8357915831663326 0.8357915831663326 is the optimal insurance with utility of -1.2007083938901026
# For a value x of 0.8375751503006013 0.8375751503006013 is the optimal insurance with utility of -1.2012228882309044
# For a value x of 0.8393587174348698 0.8393587174348698 is the optimal insurance with utility of -1.201737823674476
# For a value x of 0.8411422845691383 0.8411422845691383 is the optimal insurance with utility of -1.2022532007883313
# For a value x of 0.8429258517034068 0.8429258517034068 is the optimal insurance with utility of -1.2027690201409578
# For a value x of 0.8447094188376754 0.8447094188376754 is the optimal insurance with utility of -1.2032852823018199
# For a value x of 0.8464929859719439 0.8464929859719439 is the optimal insurance with utility of -1.2038019878413586
# For a value x of 0.8482765531062124 0.8482765531062124 is the optimal insurance with utility of -1.2043191373309972
# For a value x of 0.8500601202404809 0.8500601202404809 is the optimal insurance with utility of -1.2048367313431394
# For a value x of 0.8518436873747495 0.8518436873747495 is the optimal insurance with utility of -1.2053547704511747
# For a value x of 0.853627254509018 0.853627254509018 is the optimal insurance with utility of -1.2058732552294784
# For a value x of 0.8554108216432865 0.8554108216432865 is the optimal insurance with utility of -1.206392186253415
# For a value x of 0.8571943887775552 0.8571943887775552 is the optimal insurance with utility of -1.2069115640993395
# For a value x of 0.8589779559118237 0.8589779559118237 is the optimal insurance with utility of -1.2074313893445996
# For a value x of 0.8607615230460922 0.8607615230460922 is the optimal insurance with utility of -1.2079516625675388
# For a value x of 0.8625450901803607 0.8625450901803607 is the optimal insurance with utility of -1.2084723843474976
# For a value x of 0.8643286573146293 0.8643286573146293 is the optimal insurance with utility of -1.2089935552648157
# For a value x of 0.8661122244488978 0.8661122244488978 is the optimal insurance with utility of -1.2095151759008345
# For a value x of 0.8678957915831663 0.8678957915831663 is the optimal insurance with utility of -1.2100372468378986
# For a value x of 0.8696793587174348 0.8696793587174348 is the optimal insurance with utility of -1.2105597686593597
# For a value x of 0.8714629258517034 0.8714629258517034 is the optimal insurance with utility of -1.2110827419495764
# For a value x of 0.8732464929859719 0.8732464929859719 is the optimal insurance with utility of -1.2116061672939176
# For a value x of 0.8750300601202404 0.8750300601202404 is the optimal insurance with utility of -1.2121300452787656
# For a value x of 0.8768136272545091 0.8768136272545091 is the optimal insurance with utility of -1.2126543764915163
# For a value x of 0.8785971943887776 0.8785971943887776 is the optimal insurance with utility of -1.213179161520583
# For a value x of 0.8803807615230461 0.8803807615230461 is the optimal insurance with utility of -1.2137044009553972
# For a value x of 0.8821643286573146 0.8821643286573146 is the optimal insurance with utility of -1.2142300953864122
# For a value x of 0.8839478957915832 0.8839478957915832 is the optimal insurance with utility of -1.2147562454051053
# For a value x of 0.8857314629258517 0.8857314629258517 is the optimal insurance with utility of -1.2152828516039784
# For a value x of 0.8875150300601202 0.8875150300601202 is the optimal insurance with utility of -1.215809914576562
# For a value x of 0.8892985971943888 0.8892985971943888 is the optimal insurance with utility of -1.2163374349174159
# For a value x of 0.8910821643286573 0.8910821643286573 is the optimal insurance with utility of -1.2168654132221328
# For a value x of 0.8928657314629258 0.8928657314629258 is the optimal insurance with utility of -1.21739385008734
# For a value x of 0.8946492985971943 0.8946492985971943 is the optimal insurance with utility of -1.2179227461107018
# For a value x of 0.896432865731463 0.896432865731463 is the optimal insurance with utility of -1.2184521018909207
# For a value x of 0.8982164328657315 0.8982164328657315 is the optimal insurance with utility of -1.2189819180277413
# For a value x of 0.9 0.9 is the optimal insurance with utility of -1.2195121951219512

# %% [markdown]
# # Question 2

# %%
#Firstly, we generate the parameterization

N=500
x2 = 0.6
p=0.2
zeta=-2
y=1

#Defining functions for loop
def u_func2(p,y,x2,q,zeta,pi):
    return p*((y-x2+q-pi)**(1+zeta))/(1+zeta)+(1-p)*((y-pi)**(1+zeta))/(1+zeta)

def u_noin(p,y,x2,zeta):
    return p*((y-x2)**(1+zeta))/(1+zeta)+(1-p)*((y)**(1+zeta))/(1+zeta)

#creating loop
shape_tuple = (N)
u_ins = np.empty(shape_tuple)
q_saveny=np.empty(shape_tuple)
u_equal=u_func2(p,y,x2,0.001,zeta,pi=0.2)
q_equal=0.001
#i) Creating a grid of q.
q_new=np.linspace(0.01,x2,N)
pi=np.linspace(0.01,0.23,N)
#ii) We find corresponding pi's such that the utility with insurance is equal to insurance without insurance for every q.
for num, gridpoint in enumerate(pi):
    for index, val in enumerate(q_new):
        u_ins[index]=u_func2(p,y,x2,val,zeta,gridpoint)
        if abs(u_ins[index]-u_noin(p,y,x2,zeta))<=0.0005:
            u_equal=u_ins[index]
            q_equal=val
    
    q_saveny[num]=q_equal
    
# Now I make a function of minimum acceptable premiums for company

pi_comp=np.empty(shape_tuple)
q_comp=np.linspace(0.01,x2,N)
for w,e in enumerate(q_comp):
    pi_comp[w]=e*0.2

    
#iii) Plotting acceptable premiums with the pi(q,p) function
import matplotlib.pyplot as plt 
plt.plot(q_saveny, pi, color = "g", marker = "o", linestyle= "--", linewidth = 3,
        markersize = 2,)
plt.plot(q_comp, pi_comp, color = "y", marker = "o", linestyle= "--", linewidth = 3,
        markersize = 2, )
plt.title("Agents optimal insurance coverage")
plt.legend(["Acceptable premiums", "Minimum premiums"])
plt.xlabel("q")
plt.ylabel("pi")
plt.show()

print(u_func2(p,y,x2,q=0.6,zeta=zeta,pi=0.22))
# Out:
# -1.282051282051282

# %% [markdown]
# # Question 3

# %%
#******* Question 3 *********

#Importing distribution expressions

from scipy.stats import norm # normal distribution
from scipy.stats import beta # beta distribution

#Generating parameterization
y=1
zeta=-2
pi=0.2
gamma=0.9

#i) We generate a function that computes utility value of gamma and pi.
#ii) We plot for both the policies (0.1,0.45) and (0.2,0.9)
def g(x,y,zeta,gamma,pi):
    return (y-(1-gamma)*x-pi)**(1+zeta)/(1+zeta)

def MC(N,g,F):
    X = F.rvs(size=N) # rvs = draw N random values from F
    return np.mean(g(X,y,zeta,gamma,pi)) # apply g to X


N = 10000
#mu = 0.1
#sigma = 0.5

#Generating the beta distribution with alpha=2 and beta=7
F = beta(a=2,b=7)

mc_integral = MC(N,g,F)
print('The utility for a premium of 0.2 and benefit of 0.9 is', mc_integral)

#Now for different values

y=1
zeta=-2
pi1=0.1
gamma1=0.45
def g1(x,y,zeta,gamma1,pi1):
    return (y-(1-gamma1)*x-pi1)**(1+zeta)/(1+zeta)

def MC1(N,g1,F):
    X = F.rvs(size=N) # rvs = draw N random values from F
    return np.mean(g1(X,y,zeta,gamma1,pi1)) # apply g to X


N = 10000
#mu = 0.1
#sigma = 0.5
F = beta(a=2,b=7)

#Creatinng integral function
mc1_integral = MC1(N,g1,F)
print('The utility for a premium of 0.1 and benefit of 0.45 is', mc1_integral)
# Out:
# The utility for a premium of 0.2 and benefit of 0.9 is -1.2859247728473682
# The utility for a premium of 0.1 and benefit of 0.45 is -1.29559384944148

# %% [markdown]
# # Question 4

# %%
#*****  Question 4 ********

# First we calculate the expected value if there is no insurance
y=1
zeta=-2
def g_no(x,y,zeta,):
    return (y-x)**(1+zeta)/(1+zeta)

def MC_no(N,g_no,F):
    X = F.rvs(size=N) # rvs = draw N random values from F
    return np.mean(g_no(X,y,zeta)) # apply g to X


N = 10000
F = beta(a=2,b=7)
mcno_integral = MC_no(N,g_no,F)
print('The expected utility with no insurance is', mcno_integral)


# Now we make a loop for the maximum premium they accept:


def g_ins(x,y,zeta,gamma,pi):
    return (y-(1-gamma)*x-pi)**(1+zeta)/(1+zeta)

pi_max=np.linspace(0.01,1,50)
pi_new=0.02
util_f=0.002
for i, k in enumerate(pi_max):

    def MC_ins(N,g_ins,F):
        gamma=0.95
        X = F.rvs(size=N) # rvs = draw N random values from F
        return np.mean(g_ins(X,y,zeta,gamma,k)) # apply g to X
    val=MC_ins(N,g_ins,F)
    if abs(val-mcno_integral)<=0.05:
        pi_new=k
print('A premium of',pi_new, 'ensures that the utility is the same as with no insurance and is thus the highest premium they can charge for a benefit of 0.95')
# Out:
# The expected utility with no insurance is -1.3321579250623872
# A premium of 0.2524489795918367 ensures that the utility is the same as with no insurance and is thus the highest premium they can charge for a benefit of 0.95
